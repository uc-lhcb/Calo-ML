# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import path
import h5py
import math
import numpy as np
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D 
# This import registers the 3D projection, but is otherwise unused.

# %%
x = np.linspace(-1, 1, 32)
y = np.linspace(-1, 1, 32)
grid = np.meshgrid(x, y, sparse=False, indexing='ij')

# %%
def circular_thing(x, y):
    return x**2+y**2

# %%
x = np.linspace(-1, 1, 32)
y = np.linspace(-1, 1, 32)
def circular_thing(x, y):
    return x**2+y**2
result = circular_thing(x[:,None], y[None,:])

# %%
result[16, 16]
# Out:
# 0.0020811654526534822

# %%
np.exp(result)
# Out:
# array([[7.3890561 , 6.52166736, 5.80421749, ..., 5.80421749, 6.52166736,
#         7.3890561 ],
#        [6.52166736, 5.75609991, 5.12287026, ..., 5.12287026, 5.75609991,
#         6.52166736],
#        [5.80421749, 5.12287026, 4.55930233, ..., 4.55930233, 5.12287026,
#         5.80421749],
#        ...,
#        [5.80421749, 5.12287026, 4.55930233, ..., 4.55930233, 5.12287026,
#         5.80421749],
#        [6.52166736, 5.75609991, 5.12287026, ..., 5.12287026, 5.75609991,
#         6.52166736],
#        [7.3890561 , 6.52166736, 5.80421749, ..., 5.80421749, 6.52166736,
#         7.3890561 ]])

# %%
List = ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r']
for color in  List:
    plt.imshow(np.exp(result), cmap=color, interpolation='nearest')
    plt.colorbar()
    plt.show()

# %%
filename = "C:/Users/uri_9/Desktop/Master/TFM/4.Code/data/gamma.hdf5"

with h5py.File(filename, "r") as f:
    # List all groups
    print("Keys: %s" % str(f.keys()))
    print("Keys: ", list(f.keys()))
    a_group_key = list(f.keys())[0]

    # Get the data
    #data = list(f[a_group_key])
    #print(data)
# Out:
# Keys: KeysView(<HDF5 file "gamma.hdf5" (mode r)>)
# Keys:  ['energy', 'layer_0', 'layer_1', 'layer_2', 'overflow']

# %%
filename = "C:/Users/uri_9/Desktop/Master/TFM/4.Code/data/gamma.hdf5"
f = h5py.File(filename, "r")
data = pd.DataFrame()
keys = list(f.keys())
print("keys: ", keys)
for i, key in enumerate(keys):
    #data.insert(i, key, f[key], True)
    print(key)
    print(f[key])
    print("- - - - - - - - - -")
# Out:
# keys:  ['energy', 'layer_0', 'layer_1', 'layer_2', 'overflow']
# energy
# <HDF5 dataset "energy": shape (100000, 1), type "<f8">
# - - - - - - - - - -
# layer_0
# <HDF5 dataset "layer_0": shape (100000, 3, 96), type "<f8">
# - - - - - - - - - -
# layer_1
# <HDF5 dataset "layer_1": shape (100000, 12, 12), type "<f8">
# - - - - - - - - - -
# layer_2
# <HDF5 dataset "layer_2": shape (100000, 12, 6), type "<f8">
# - - - - - - - - - -
# overflow
# <HDF5 dataset "overflow": shape (100000, 3), type "<f8">
# - - - - - - - - - -

# %% [markdown]
# LOAD DATA

# %%
import torch
from helpers.training import *
from helpers.data import *
from helpers.utilities import *
from models.VAE import *
import matplotlib.pyplot as plt

# %%
df = pd.read_hdf('/share/lazy/CaloML/CaloGan/CaloGan_photons.h5')
array = torch.Tensor([array.tolist() for array in df['EnergyDeposit'].values]).reshape(50000, 30, 30)

# %%
Xc = torch.zeros(50000)
Yc = torch.zeros(50000)
for x_coord in range(0, 30):    
    for y_coord in range(0, 30):
        Xc += array[:, x_coord, y_coord]*(abs(x_coord-15))
        Yc += array[:, x_coord, y_coord]*(abs(y_coord-15))
Xc /= array.sum(-1).sum(-1)
Yc /= array.sum(-1).sum(-1)

RMS_width = torch.zeros(50000)
for x_coord in range(0, 30):    
    for y_coord in range(0, 30):
        RMS_width += array[:, x_coord, y_coord] * ((-Xc+abs(x_coord-15))**2 + (-Yc+abs(y_coord-15))**2)
RMS_width /= array.sum(-1).sum(-1)

# %%
plt.hist(RMS_width.numpy()[RMS_width.numpy() < 5], bins=100)
plt.show()

# %%
bools = RMS_width.numpy() > 5
outliers = torch.log(array[bools]+1)
i = 0

# %%
i += 1
plot_3d_bar(outliers[i].numpy(), 30, 'Predicted distribution (log scale)', f"delete.jpg")

# %% [markdown]
# CREATE ENERGY HISTOGRAMS

# %%
#Resahpe energy grids
def reshape_energy_grid(energy_grid, new_shape=30):
    reshaped_grid = energy_grid.reshape((30, 30))
    return reshaped_grid

def create_cluster(energy_grid, num_of_cells):
    rows_0 = len(energy_grid)
    columns_0 = len(energy_grid[0])
    #print("original sizes: ", rows_0, columns_0)
    cells_dim = int(rows_0/math.sqrt(num_of_cells))
    #print("cells_dim: ", cells_dim)
    columns_1 = int(columns_0/cells_dim)
    rows_1 = int(rows_0/cells_dim)
    
    new_grid = np.zeros((rows_1,columns_1))

    for i in range(rows_1):
        for j in range(columns_1):
            cluster = energy_grid[int(i*cells_dim):int((i+1)*cells_dim-1),int(j*cells_dim):int((j+1)*cells_dim-1)]
            new_grid[i][j] = sum(sum(cluster))/len(cluster) 
    
    return new_grid
        
# Function to plot rowsXcolumns images from startiing point rand.
def plot_energy_grid(energy_grid_to_plot, rows=2, columns=2):
    fig=plt.figure(figsize=(12, 12))
    for i in range(1, columns*rows +1):
        plt.imshow(energy_grid_to_plot)
    plt.show()

def plot_3d_bar(data, cells): 
    # setup the figure and axes
    fig = plt.figure(figsize=(32, 12))
    ax1 = fig.add_subplot(121, projection='3d')

    # get the coordinates
    x = list(range(0, cells))
    y = list(range(0, cells))
    _xx, _yy = np.meshgrid(x, y)
    x, y = _xx.ravel(), _yy.ravel()

    #Get top & down values
    top = data.ravel()
    bottom = np.zeros_like(top)
    width = depth = 1

    ax1.bar3d(x, y, bottom, width, depth, top, shade=True)
    ax1.set_title('Shaded')

    plt.show()

# %%
energy_grids = df.EnergyDeposit.tolist()
energy_grid = energy_grids[1]
reshaped_energy_grids = reshape_energy_grid(energy_grid)
new_grid = create_cluster(reshaped_energy_grids, 36)
plot_energy_grid(new_grid, rows=2, columns=2)
plot_3d_bar(new_grid, cells=6)

# %%
import glob
import imageio

image_path = "Generator_result.png"
image = imageio.imread(image_path)
data = np.asarray(image)
#reshaped_energy_grids = reshape_energy_grids(data[0])
#new_grid = create_cluster(reshaped_energy_grids, 36)
#plot_energy_grid(new_grid, rows=2, columns=2)
#plot_3d_bar(new_grid, cells=6)

# %% [markdown]
# PLOT TIME SPENT

# %%
# %%
# Gráfico circular o de pastel
# https://es.wikipedia.org/wiki/Anexo:Destinos_tur%C3%ADsticos_mundiales

turistas = [35, 35, 7, 20, 3]
paises = ['Deliverables', 'Code', 'Dataset', 'Study', 'Tracing']

plt.pie(turistas, labels=paises,
        autopct='%1.1f%%', shadow=False, startangle=90)
plt.title('Time spent')
plt.show()

# %% [markdown]
# PLOT ENERGY GRIDS

# %%
#Resahpe energy grids
def reshape_energy_grids(energy_grids, new_shape=30):
    reshaped_grids = energy_grids.copy()
    for i, val in enumerate(reshaped_grids):
        reshaped_grids[i] = val.reshape((30, 30))
    return reshaped_grids

# Function to plot rowsXcolumns images from startiing point rand.
def plot_energy_grids(energy_grids_to_plot, rows=3, columns=3, rand=500):
    fig=plt.figure(figsize=(12, 12))
    for i in range(1, columns*rows +1):
        fig.add_subplot(rows, columns, i)
        plt.imshow(energy_grids_to_plot[rand + i])
    plt.show()

# %%
# Coger la columna energy grids y pasarla a lista
energy_grids = df.EnergyDeposit.tolist()
reshaped_energy_grids = reshape_energy_grids(energy_grids)
plot_energy_grids(reshaped_energy_grids)

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

# celes de 2 cm.
mu = 30
sigma = 16.60
#sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 50000)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.xlabel("Energy deposit (cm)")
plt.ylabel("Y axis label")
plt.show()

# %% [markdown]
# PLOT HISTOGRAM OF THE ENERGY WIDTH DATASET

# %% [markdown]
# amplada = numero de pixels entre un canvi de magnitud i el baricentre, definint el baricentre com la unió dels 4 pixels centrals.
#
# preprocess = treure una fila de pixels de cada direcció per tenir un pixel com a baricentre.
#
# Existeix una amplada horitzontal que es la distancia de la linea central.
#
# Iterar imatges calcular l'amplada.
#
# Fer la mitjana amb les desviacions estandards i comparar el número que em surt de la generació d'imatges.
#
# Fer-ho per el dataset original i les imatges generades.

# %%
import statistics 

def compute_avg_energy(reshapaed_energy_grids):
    total_energy = 0
    for counter, image in enumerate(reshapaed_energy_grids):
        total_energy += sum(sum(image))
    total_energy = total_energy/50000
    print("The average energy per image is: " + str(total_energy))
    return total_energy

def find_baricenter(image):
    baricenter = [0,0]
    total_energy = sum(sum(image))
    for row, energy_row in enumerate(image):
        for column, energy in enumerate(energy_row):
            if energy > 0.0:
                baricenter[0] += (row+1)*energy/total_energy
                baricenter[1] += (column+1)*energy/total_energy
    #print("Image energy: " + str(total_energy))
    #print("Image baricenter: " + str(baricenter))
    return baricenter, total_energy

def iterate_image(distances, image):
    baricenter, total_energy = find_baricenter(image)
    for row, energy_row in enumerate(image):
        for column, energy in enumerate(energy_row):
            if energy > 0.0:
                #print("The energy in the cell " + str(row) + "," + str(column) + " is " + str(energy))
                x = math.pow((row+1)*energy/total_energy - baricenter[0],2)*energy/total_energy
                y = math.pow((column+1)*energy/total_energy - baricenter[1],2)*energy/total_energy
                distances.append(math.sqrt(x + y))

def compute_avg_distance(reshapaed_energy_grids):
    avg_distances_per_images = []
    sd_distances_per_images = []
    for counter, image in enumerate(reshapaed_energy_grids):
        if counter%5000 == 0.0:
            print("Computing image number " + str(counter) + " of " + str(len(reshapaed_energy_grids)))
        distances = []
        for image_direction in [image, np.flip(image), np.transpose(image), np.flip(np.transpose(image))]:
            iterate_image(distances, image_direction)

        avg_distances_per_images.append(sum(distances)/len(distances))
        sd_distances_per_images.append(statistics.stdev(distances))

    avg_whole_dataset_distances = sum(avg_distances_per_images)/len(avg_distances_per_images)
    sd_distances_per_images_squared = []
    for sd in sd_distances_per_images:
        sd_distances_per_images_squared.append(math.pow(sd,2))
    avg_whole_dataset_sd = math.sqrt(sum(sd_distances_per_images_squared))/len(avg_distances_per_images)
    
    print("The avg distance is " + str(avg_whole_dataset_distances) + " cells with an error of " + str(avg_whole_dataset_sd) + " cells.")
    print("The avg distance is " + str(avg_whole_dataset_distances*2) + " cms with an error of " + str(avg_whole_dataset_sd*2) + " cms.")

# %%
compute_avg_energy(reshapaed_energy_grids)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-d53fd660a82f> in <module>
# ----> 1 compute_avg_energy(reshapaed_energy_grids)
#
# <ipython-input-104-afe2880b80be> in compute_avg_energy(reshapaed_energy_grids)
#       4     total_energy = 0
#       5     for counter, image in enumerate(reshapaed_energy_grids):
# ----> 6         total_energy += sum(sum(sum(image)))
#       7     total_energy = total_energy/50000
#       8     print("The average energy per image is: " + str(total_energy))
#
# TypeError: 'numpy.float64' object is not iterable

# %%
df = pd.read_hdf('../data/CaloGan_photons.h5')
energy_grids = df.EnergyDeposit.tolist()
reshapaed_energy_grids = reshape_energy_grids(energy_grids)

# %%
reshapaed_energy_grids2 = reshapaed_energy_grids[2500:2550]
compute_avg_distance(reshapaed_energy_grids)
# Out:
# Computing image number 0 of 50000
# Computing image number 5000 of 50000
# Computing image number 10000 of 50000
# Computing image number 15000 of 50000
# Computing image number 20000 of 50000
# Computing image number 25000 of 50000
# Computing image number 30000 of 50000
# Computing image number 35000 of 50000
# Computing image number 40000 of 50000
# Computing image number 45000 of 50000
# The avg distance is 1.0310977235907905 cells with an error of 0.006113701952754442 cells.
# The avg distance is 2.062195447181581 cms with an error of 0.012227403905508884 cms.

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

mu = 2.06
sigma = 0.01
mu_fake = 3.30
sigma_fake = 0.04
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
x_fake = np.linspace(mu_fake - 3*sigma_fake, mu_fake + 3*sigma_fake, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.plot(x_fake, stats.norm.pdf(x_fake, mu_fake, sigma_fake))
plt.xlabel("Shower width (cm)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# GENERATE INPUT DATA

# %%
def generate_input_data(data, length=500, noise_dist="g"):
    # Get particles position from dataframe removing Z axis
    position = np.array(data.ParticlePoint.to_list())[:,:-1]
    # Get particles momentum from dataframe
    momentum = np.array(data.ParticleMomentum.to_list())
    # Concatenate momentum + position
    input_data = np.concatenate((position, momentum), axis=1)
    length = length - len(input_data[0])
    # Generate noise for each example we have
    if noise_dist == "g":
        mu = 0 
        sigma = 1
        noise = []
        for i in range(input_data.shape[0]):
            noise.append(np.random.normal(mu, sigma, length).tolist())
        noise = np.asarray(noise)
    # Joint noise and real data
    return np.concatenate((input_data, noise), axis=1)

# %%
noised_input_data = generate_input_data(df, length=500)

# %%
noised_input_data.shape

# %%
x_parameters = ["ParticlePoint", "ParticleMomentum"]

params = []
for x_param in x_parameters:
    params.append(np.array(df[str(x_param)].to_list())[:, :-1])
    
input_params = np.concatenate(params, axis=1)
